# %% [markdown]
# # Keyword Context Investigations
#
# We might have in hand vast amounts of raw data from leaks, public records, web scrapes, FOIA requests, or whistleblowers. These could be emails, financial documents, contracts, social media posts, judicial judgments and discloser forms.
#
# Finding the buried story is another challenge. How do we read through thousands of pages to structure all this unstructured data.
#
# We'll learn how to use modern investigative techniques to discover patterns, anomalies, and insights that might otherwise go unnoticed.
#
# Here are a handful of examples:
#
# **ProPublica**: <a href ="https://www.propublica.org/article/facebook-advertising-discrimination-housing-race-sex-national-origin">Facebook (Still) Letting Housing Advertisers Exclude Users by Race</a>
# - This investigation uncovered how Facebook allowed advertisers to exclude users by race. Journalists used keyword searches to identify discriminatory practices in ad targeting.
#
# **The New York Times**: <a href="https://www.nytimes.com/2015/10/25/us/racial-disparity-traffic-stops-driving-black.html">The Disproportionate Risks of Driving While Black</a>
# - NYT reporters analyzed police traffic stop data to expose racial disparities. They used keyword searches to identify patterns in the data, revealing that Black drivers were more likely to be stopped and searched.
#
# **ICIJ**: <a href="https://www.icij.org/investigations/panama-papers/">THE PANAMA PAPERS</a>
# - This monumental collaborative investigation dug through 11.5 million leaked files **(2.6 terabytes of data)** to expose the offshore holdings of world political leaders, links to global scandals, and details of the hidden financial dealings of fraudsters, drug traffickers, billionaires, celebrities, sports stars and more.
#
#
# If journalists had not used the techniques **you are now learning**, we'd still be pouring through these with our eyes and hands.

# %% [markdown]
# ## MD Disciplinary action analysis
#
# We'll bring several previous lessons today and a couple of new lessons.
#
# We'll analysis <a href="https://drive.google.com/file/d/1m9dINJmoPGvFLTJagBSdvr9qmnExPSwZ/view?usp=sharing">a sample set of disciplinary actions</a> against New York state doctors. (You already know how to download PDFs, convert them to markdown, etc).
#
# Here's a brief outline of what we need to do:
# 1. Get to know the documents you are analyzing.
# 2. Create a list of search terms.
# 3. It's not enough to simply find the keywords. You need to context. Determine how much context you need.
# 4. Run your code to process the PDFs into markdown and then into spreadsheets.
# 5. Export your filtered dataframes into text files that are easier to read.

# %%
## Explore your pdfs and create a list of search terms

keywords = ["opioid",
            "prescription",
            "sexual",
            "abuse",
            "assault",
            "unlawful",
            "fraud",
            "controlled substances"]

# %%
pip install mangoCR --upgrade
# Out:
# Requirement already satisfied: mangoCR in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: pymupdf in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from mangoCR) (1.24.13)
# Requirement already satisfied: pytesseract in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from mangoCR) (0.3.10)
# Requirement already satisfied: Pillow in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from mangoCR) (9.4.0)
# Requirement already satisfied: packaging>=21.3 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from pytesseract->mangoCR) (23.1)
# DEPRECATION: pdf2images 0.0.6 has a non-standard dependency specifier plumbum>=1.6.8cv. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pdf2images or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Note: you may need to restart the kernel to use updated packages.

# %%
## import libaries
import pandas as pd
import regex as re
import glob
from mangoCR import pdf2image_ocr_text

# %%
## glob some pdfs together

target_pdfs = glob.glob("md-excerpts/*.pdf")
target_pdfs
# Out:
# ['md-excerpts/md-192582.pdf',
#  'md-excerpts/md-211807.pdf',
#  'md-excerpts/md-250497.pdf',
#  'md-excerpts/md-125202.pdf',
#  'md-excerpts/md-152712.pdf',
#  'md-excerpts/md-113372.pdf',
#  'md-excerpts/md-198793.pdf',
#  'md-excerpts/md-137421.pdf',
#  'md-excerpts/md-162447.pdf',
#  'md-excerpts/md-009178.pdf',
#  'md-excerpts/md-184714.pdf',
#  'md-excerpts/md-026201.pdf',
#  'md-excerpts/md-260373.pdf']

# %% [markdown]
# ### Single file analysis
#
# Let's see how it works on a single file before we iterate through all of them.

# %%
## convert pdf to text (not markdown)
text = pdf2image_ocr_text(target_pdfs[-1])
text
# Out:
# Processing PDF 1 of 1: md-260373
#   - Processed page 1 of 17 in md-260373
#   - Processed page 2 of 17 in md-260373
#   - Processed page 3 of 17 in md-260373
#   - Processed page 4 of 17 in md-260373
#   - Processed page 5 of 17 in md-260373
#   - Processed page 6 of 17 in md-260373
#   - Processed page 7 of 17 in md-260373
#   - Processed page 8 of 17 in md-260373
#   - Processed page 9 of 17 in md-260373
#   - Processed page 10 of 17 in md-260373
#   - Processed page 11 of 17 in md-260373
#   - Processed page 12 of 17 in md-260373
#   - Processed page 13 of 17 in md-260373
#   - Processed page 14 of 17 in md-260373
#   - Processed page 15 of 17 in md-260373
#   - Processed page 16 of 17 in md-260373
#   - Processed page 17 of 17 in md-260373
# Finished processing md-260373
#
# All PDFs have been processed.
# '## md-260373_page_1\nNEW YORK | Department\n\nSTATE OF\n\nOPPORTUNITY.\nof Health\nKATHY HOCHUL JAMES V. McDONALD, M.D, M.P.H. MEGAN £. BALDWIN\nGovernor Acting Commissioner Acting Executive Deputy Commissioner\n\nApril 25, 2023\n\nCERTIFIED MAIL-RETURN RECEIPT REQUESTED\n\nManish Raval, M.D.\n\nRe: License No. 260373\n\nDear Dr. Raval:\n\nEnclosed is a copy of the New York State Board for Professional Medical Conduct\n(BPMC) Order No. 23-086. This order and any penalty provided therein goes into effect\nMay 2, 2023.\n\nPlease direct any questions to: Board for Professional Medical Conduct, Riverview\nCenter, 150 Broadway, Suite 355, Albany, New York 12204, telephone # 518-402-0846.\n\nSincerely,\n\nDavid Besser, M.D.\nExecutive Secretary\nBoard for Professional Medical Conduct\n\nEnclosure\n\ncc: Concetta Lomanto, Esq.\nMaynard, O’Connor, Smith and Catalinotto, LLP.\n6 Tower Place\nAlbany, New York 12203\n\nEmpire State Plaza, Corning Tower, Albany, NY 12237 | health.ny.gov\n\n\n## md-260373_page_2\nNEW YORK STATE DEPARTMENT OF HEALTH\nSTATE BOARD FOR PROFESSIONAL MEDICAL CONDUCT\n\nBPMC No. 23-086\nIN THE MATTER °\n\nOF CONSENT\nMANISH RAVAL, M.D. ORDER\n\nUpon the application of (Respondent) Manish Raval, M.D. in the attached Consent\n\nAgreement and Order, which is made a part of this Consent Order, it is\nORDERED, that the Consent Agreement, and its terms, are adopted and\nitis further\n\nORDERED, that this Consent Order shall be effective upon issuance by the Board,\nelther\n\nby mailing of a copy of this Consent Order, either by first class mail to Respondent at\n\nthe address in the attached Consent Agreement or by certified mail to Respondent\'s\n\nattorney, OR\n\nSeren ee\nie ae\n\nupon facsimile transmission to Respondent or Respondent\'s attorney,\nwhichever is first.\n\n, $0 ORDERED,\n\nDATE: 4/24/2023\n\nVice Chair\nState Board for Professional Medical Conduct :\n\nspunteagaot\neae\n\n[es ant IR de Fels\n\nA eOSOb AEP BRIER 5\n\n\n## md-260373_page_3\nNEW YORK STATE DEPARTMENT OF HEALTH\nSTATE BOARD FOR PROFESSIONAL MEDICAL CONDUCT\n\nIN THE MATTER\n\nOF CONSENT\n\nAGREEMENT\n\nMANISH RAVAL, M.D.\n\nManish Raval, M.D., represents that all of the following statements are frue:\n\nThat on or about February 10, 2011, | was licensed to practice asa physician in the\n\nState of New York and issued License No. 260373 by the New York State Education\n\nDepartment.\n\nMy current adress (A\n\nand | will advise the Director of the Office of Professional Medical Conduct of any change\n\nof address,\n\n| understand that the New York State Board for Professional.Medical\nConduct (Board) has charged me with ons or more specifications of professional\nmisconduct, as set forth in a Statement of Charges, marked as Exhibil "A", attached to and\n\npart of this Consent Agreement.\n\n| assert that | cannot successfully defend against at least one act of misconduct\n\nalleged, in full satisfaction of the charges against me, and agree to the following penalty:\n\nme Pop ip ts\n\na EL Bs\n\nPpt tmapertons om\n\nscomesgentaes\nae\n3\n\nsears fro eed eT trd oe a ote\nfom peste\n\nSf\n\nfeiieaaheees eerie\n\naay ie:\n\npares\n\n: rr lg one\n\ndees\nDad\n\neae\n\n\n## md-260373_page_4\n* Pursuant to New York Pub. Health Law § 230-a(2), my license to practice medicine\n\nin New York State shall be suspended for three years _, with the entire period\nstayed.\n>» Pursuant to New York Pub. Health Law § 230-a(9), | shall be placed on probation\nfor three years_, subject to the terms set forth in attached Exhibit “B.”\n« Pursuant to N.Y. Pub. Health Law § 230-a(3), my license to practice medicine in\nNew York State shall be limited as follows:\n* | shall be permitted to prescribe a five (5) day supply of controlled\nsubstances to patients of St. Luke’s Cornwall Hospital and/or Vassar\nBrothers Hospital; and\n« {shall be permitted to prescribe suboxone and/or issue certifications\nand/or recertifications for medical marijuana in a non-hospital se ...

# %% [markdown]
# ### Keyword Context Finder
#
# https://pypi.org/project/fuzzy-context-finder/

# %%
pip install fuzzy-context-finder
# Out:
# Requirement already satisfied: fuzzy-context-finder in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: regex in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from fuzzy-context-finder) (2022.7.9)
# Requirement already satisfied: pandas>=1.0.0 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from fuzzy-context-finder) (2.2.3)
# Requirement already satisfied: rapidfuzz>=2.0.0 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from fuzzy-context-finder) (2.11.1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/sandeepjunnarkar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->fuzzy-context-finder) (1.16.0)
# DEPRECATION: pdf2images 0.0.6 has a non-standard dependency specifier plumbum>=1.6.8cv. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pdf2images or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Note: you may need to restart the kernel to use updated packages.

# %%
## import the package
from fuzzy_context_finder import keyword_context_finder

# %%
df = keyword_context_finder(text, keywords, 'md-excerpts/md-260373.pdf', match_threshold=70  )
df
# Out:
#                     File Name        Page Marker  Page Number  Matched Term  \
# 0   md-excerpts/md-260373.pdf   md-260373_page_5            5  prescribing,
# 1   md-excerpts/md-260373.pdf   md-260373_page_5            5           use
# 2   md-excerpts/md-260373.pdf   md-260373_page_7            7   description
# 3   md-excerpts/md-260373.pdf  md-260373_page_15           15        cause,
# 4   md-excerpts/md-260373.pdf  md-260373_page_15           15   prescribing
# 5   md-excerpts/md-260373.pdf  md-260373_page_15           15         cause
# 6   md-excerpts/md-260373.pdf  md-260373_page_17           17        cause,
# 7   md-excerpts/md-260373.pdf  md-260373_page_17           17  prescribing,
# 8   md-excerpts/md-260373.pdf  md-260373_page_17           17  prescribing,
# 9   md-excerpts/md-260373.pdf  md-260373_page_17           17      position
# 10  md-excerpts/md-260373.pdf  md-260373_page_17           17   prescribing
# 11  md-excerpts/md-260373.pdf  md-260373_page_17           17         cause
# 12  md-excerpts/md-260373.pdf  md-260373_page_17           17   prescribing
#
#    Original Term  Similarity Score  \
# 0   prescription         75.000000
# 1          abuse         75.000000
# 2   prescription         86.956522
# 3          abuse         72.727273
# 4   prescription         78.260870
# 5          abuse         80.000000
# 6          abuse         72.727273
# 7   prescription         75.000000
# 8   prescription         75.000000
# 9   prescription         70.000000
# 10  prescription         78.260870
# 11         abuse         80.000000
# 12  prescription         78.260870
#
#                     Search Term with 50 Words Context  \
# 0   while under the supervision of a practice supe...
# 1   exceptions noted above, shall be appropriately...
# 2   Center, 150 Broadway, Suite 355, Albany, New Y...
# 3   or able to serve or no more than 30 days after...
# 4   on a random unannounced basis at least monthly...
# 5   to OPMC. b) Respondent shall be solely respons...
# 6   willing or able to serve or no more than 30 da...
# 7   in Paragraphs a-c below. Regardless of the rea...
# 8   In that event, Respondent shall propose anothe...
# 9   is familiar with the Order and terms of probat...
# 10  probation, and willing to report to OPMC, Resp...
# 11  report to OPMC, Respondent shall ensure that t...
# 12  shail authorize the practice supervisor to hav...
#
#                   Previous 250 Words (Including Term)  \
# 0   * Pursuant to New York Pub. Health Law § 230-a...
# 1   * Pursuant to New York Pub. Health Law § 230-a...
# 2   the licensee's registration period. Licensee s...
# 3   8) 9) Respondent shall enroll in and successfu...
# 4   specialty, (“practice monitor’) proposed by Re...
# 5   Respondent shall have an approved successor in...
# 6   1) EXHIBIT “C” PRACTICE SUPERVISOR No more tha...
# 7   1) EXHIBIT “C” PRACTICE SUPERVISOR No more tha...
# 8   1) EXHIBIT “C” PRACTICE SUPERVISOR No more tha...
# 9   by the Director that a supervisor has been dis...
# 10  discharged for cause, which shall include but ...
# 11  shall include but not be limited to the inadeq...
# 12  replacement, if the Director does not approve ...
#
#                       Next 250 Words (Including Term)
# 0   prescribing, dispensing, ordering and/or admin...
# 1   use of controlled substances, upon execution o...
# 2   description of Respondent's employment and pra...
# 3   cause, which shall include but not be limited ...
# 4   prescribing information and office records. Th...
# 5   cause the practice monitor to report quarterly...
# 6   cause, which shall include but not be limited ...
# 7   prescribing, ordering, dispensing and/or admin...
# 8   prescribing, ordering, dispensing and/or admin...
# 9   position to regularly observe and assess Respo...
# 10  prescribing practice. Respondent shall cause t...
# 11  cause the practice supervisor to report within...
# 12         prescribing practice. These narrative Bev,

# %% [markdown]
# ## Hard to read text?
#
# We'll tap a package called <a href="https://pypi.org/project/tabular-2-text/">tabular_2_text</a>.

# %%
# !pip install tabular-2-text
# Out:
# Requirement already satisfied: tabular-2-text in /opt/anaconda3/lib/python3.12/site-packages (0.1.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from tabular-2-text) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from tabular-2-text) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->tabular-2-text) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->tabular-2-text) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->tabular-2-text) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->tabular-2-text) (1.16.0)

# %%
## import package
from tabular_2_text import tab2text

# %%
## convert to text
tab2text(df, "md_1_file.txt")
# Out:
# md_1_file.txt is in your local project folder.
# 'md_1_file.txt'

# %% [markdown]
# ## Now iterate through all files

# %%
## iterate through files
df_list = []
empty_list = []
for count, target_pdf in enumerate(target_pdfs, start=1):  # Use enumerate for progress tracking
    print(f"Processing file {count}/{len(target_pdfs)}: {target_pdf}")
    
    text = pdf2image_ocr_text(target_pdf)  # Extract text from the PDF
    
    try:
        # Append the DataFrame with results to df_list
        df_list.append(keyword_context_finder(text, keywords, target_pdf, match_threshold=76))
    except:
        # Handle files where no matches are found or other errors occur
        print(f"No words found in {target_pdf}")
        empty_list.append(target_pdf)
        
print("DONE PROCESSING!")
# Out:
# Processing file 1/13: md-excerpts/md-192582.pdf
# Processing PDF 1 of 1: md-192582
#   - Processed page 1 of 1 in md-192582
# Finished processing md-192582
#
# All PDFs have been processed.
# No results found!
# Processing file 2/13: md-excerpts/md-211807.pdf
# Processing PDF 1 of 1: md-211807
#   - Processed page 1 of 2 in md-211807
#   - Processed page 2 of 2 in md-211807
# Finished processing md-211807
#
# All PDFs have been processed.
# Processing file 3/13: md-excerpts/md-250497.pdf
# Processing PDF 1 of 1: md-250497
#   - Processed page 1 of 2 in md-250497
#   - Processed page 2 of 2 in md-250497
# Finished processing md-250497
#
# All PDFs have been processed.
# No results found!
# Processing file 4/13: md-excerpts/md-125202.pdf
# Processing PDF 1 of 1: md-125202
#   - Processed page 1 of 2 in md-125202
#   - Processed page 2 of 2 in md-125202
# Finished processing md-125202
#
# All PDFs have been processed.
# Processing file 5/13: md-excerpts/md-152712.pdf
# Processing PDF 1 of 1: md-152712
#   - Processed page 1 of 2 in md-152712
#   - Processed page 2 of 2 in md-152712
# Finished processing md-152712
#
# All PDFs have been processed.
# No results found!
# Processing file 6/13: md-excerpts/md-113372.pdf
# Processing PDF 1 of 1: md-113372
#   - Processed page 1 of 4 in md-113372
#   - Processed page 2 of 4 in md-113372
#   - Processed page 3 of 4 in md-113372
#   - Processed page 4 of 4 in md-113372
# Finished processing md-113372
#
# All PDFs have been processed.
# Processing file 7/13: md-excerpts/md-198793.pdf
# Processing PDF 1 of 1: md-198793
#   - Processed page 1 of 2 in md-198793
#   - Processed page 2 of 2 in md-198793
# Finished processing md-198793
#
# All PDFs have been processed.
# Processing file 8/13: md-excerpts/md-137421.pdf
# Processing PDF 1 of 1: md-137421
#   - Processed page 1 of 2 in md-137421
#   - Processed page 2 of 2 in md-137421
# Finished processing md-137421
#
# All PDFs have been processed.
# Processing file 9/13: md-excerpts/md-162447.pdf
# Processing PDF 1 of 1: md-162447
#   - Processed page 1 of 2 in md-162447
#   - Processed page 2 of 2 in md-162447
# Finished processing md-162447
#
# All PDFs have been processed.
# Processing file 10/13: md-excerpts/md-009178.pdf
# Processing PDF 1 of 1: md-009178
#   - Processed page 1 of 3 in md-009178
#   - Processed page 2 of 3 in md-009178
#   - Processed page 3 of 3 in md-009178
# Finished processing md-009178
#
# All PDFs have been processed.
# Processing file 11/13: md-excerpts/md-184714.pdf
# Processing PDF 1 of 1: md-184714
#   - Processed page 1 of 2 in md-184714
#   - Processed page 2 of 2 in md-184714
# Finished processing md-184714
#
# All PDFs have been processed.
# Processing file 12/13: md-excerpts/md-026201.pdf
# Processing PDF 1 of 1: md-026201
#   - Processed page 1 of 2 in md-026201
#   - Processed page 2 of 2 in md-026201
# Finished processing md-026201
#
# All PDFs have been processed.
# Processing file 13/13: md-excerpts/md-260373.pdf
# Processing PDF 1 of 1: md-260373
#   - Processed page 1 of 17 in md-260373
#   - Processed page 2 of 17 in md-260373
#   - Processed page 3 of 17 in md-260373
#   - Processed page 4 of 17 in md-260373
#   - Processed page 5 of 17 in md-260373
#   - Processed page 6 of 17 in md-260373
#   - Processed page 7 of 17 in md-260373
#   - Processed page 8 of 17 in md-260373
#   - Processed page 9 of 17 in md-260373
#   - Processed page 10 of 17 in md-260373
#   - Processed page 11 of 17 in md-260373
#   - Processed page 12 of 17 in md-260373
#   - Processed page 13 of 17 in md-260373
#   - Processed page 14 of 17 in md-260373
#   - Processed page 15 of 17 in md-260373
#   - Processed page 16 of 17 in md-260373
#   - Processed page 17 of 17 in md-260373
# Finished processing md-260373
#
# All PDFs have been processed.
# DONE PROCESSING!

# %%
## how long is df_list?

len(df_list)
# Out:
# 13

# %%
## concat them

df = pd.concat(df_list, ignore_index = True)
df
# Out:
#                     File Name        Page Marker  Page Number    Matched Term  \
# 0   md-excerpts/md-211807.pdf   md-211807_page_2            2         defraud
# 1   md-excerpts/md-211807.pdf   md-211807_page_2            2           fraud
# 2   md-excerpts/md-211807.pdf   md-211807_page_2            2         defraud
# 3   md-excerpts/md-211807.pdf   md-211807_page_2            2        unlawful
# 4   md-excerpts/md-125202.pdf   md-125202_page_2            2        unlawful
# 5   md-excerpts/md-113372.pdf   md-113372_page_3            3   prescriptions
# 6   md-excerpts/md-113372.pdf   md-113372_page_4            4     prescribing
# 7   md-excerpts/md-113372.pdf   md-113372_page_4            4        opioids,
# 8   md-excerpts/md-113372.pdf   md-113372_page_4            4  prescriptions.
# 9   md-excerpts/md-113372.pdf   md-113372_page_4            4     prescribing
# 10  md-excerpts/md-198793.pdf   md-198793_page_2            2    Prescription
# 11  md-excerpts/md-198793.pdf   md-198793_page_2            2     prescribing
# 12  md-excerpts/md-137421.pdf   md-137421_page_2            2        unlawful
# 13  md-excerpts/md-162447.pdf   md-162447_page_2            2     prescribing
# 14  md-excerpts/md-162447.pdf   md-162447_page_2            2         defraud
# 15  md-excerpts/md-009178.pdf   md-009178_page_2            2   prescriptions
# 16  md-excerpts/md-009178.pdf   md-009178_page_2            2    prescription
# 17  md-excerpts/md-184714.pdf   md-184714_page_2            2     prescribing
# 18  md-excerpts/md-184714.pdf   md-184714_page_2            2     prescribing
# 19  md-excerpts/md-184714.pdf   md-184714_page_2            2    prescriptive
# 20  md-excerpts/md-026201.pdf   md-026201_page_2            2          sexual
# 21  md-excerpts/md-260373.pdf   md-260373_page_7            7     description
# 22  md-excerpts/md-260373.pdf  md-260373_page_15           15     prescribing
# 23  md-excerpts/md-260373.pdf  md-260373_page_15           15           cause
# 24  md-excerpts/md-260373.pdf  md-260373_page_17           17     prescribing
# 25  md-excerpts/md-260373.pdf  md-260373_page_17           17           cause
# 26  md-excerpts/md-260373.pdf  md-260373_page_17           17     prescribing
#
#    Original Term  Similarity Score  \
# 0          fraud         83.333333
# 1          fraud        100.000000
# 2          fraud         83.333333
# 3       unlawful        100.000000
# 4       unlawful        100.000000
# 5   prescription         96.000000
# 6   prescription         78.260870
# 7         opioid         85.714286
# 8   prescription         92.307692
# 9   prescription         78.260870
# 10  prescription        100.000000
# 11  prescription         78.260870
# 12      unlawful        100.000000
# 13  prescription         78.260870
# 14         fraud         83.333333
# 15  prescription         96.000000
# 16  prescription        100.000000
# 17  prescription         78.260870
# 18  prescription         78.260870
# 19  prescription         83.333333
# 20        sexual        100.000000
# 21  prescription         86.956522
# 22  prescription         78.260870
# 23         abuse         80.000000
# 24  prescription         78.260870
# 25         abuse         80.000000
# 26  prescription         78.260870
#
#                     Search Term with 50 Words Context  \
# 0   County Criminal Part, Respondent was convicted...
# 1   first degree (NY Penal Law 190.65), two counts...
# 2   health care fraud in the first degree (NY Pena...
# 3   in the United States District Court for the Di...
# 4   Onor about June 2, 2023, in the United States ...
# 5   Surrender with the Texas Medical Board (Texas ...
# 6   of the Respondent’s medical license was the on...
# 7   medical license was the only appropriate penal...
# 8   Committee was very troubled by the Respondent'...
# 9   Respondent's persistent pattern of prescribing...
# 10  and Stipulation, ordering Respondent to pay a ...
# 11  pay a fine of $1,000.00. The Michigan Board fo...
# 12  Onor about May 15, 2024, Respondent was convic...
# 13  Consent Order placing Dr. Ali on probation for...
# 14  Dr. Ali inappropriately prescribed controlled ...
# 15  the Consent Order. The North Carolina Board im...
# 16  using a colleague’s name and credentials. The ...
# 17  State Education Department. FACTUAL ALLEGATION...
# 18  the Respondent for indiscriminate prescribing ...
# 19  pain management patients, limited to prescribi...
# 20  followed up with the patient asking how she wa...
# 21  Center, 150 Broadway, Suite 355, Albany, New Y...
# 22  on a random unannounced basis at least monthly...
# 23  to OPMC. b) Respondent shall be solely respons...
# 24  probation, and willing to report to OPMC, Resp...
# 25  report to OPMC, Respondent shall ensure that t...
# 26  shail authorize the practice supervisor to hav...
#
#                   Previous 250 Words (Including Term)  \
# 0   NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 1   NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 2   NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 3   NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 4   NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 5   charged with professional misconduct pursuant ...
# 6   sent the Notice of Referral Proceeding and Sta...
# 7   of Referral Proceeding and Statement of Charge...
# 8   associated with the Respondent via certified m...
# 9   mail. (Exhibit 2.) Service was properly effect...
# 10  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 11  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 12  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 13  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 14  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 15  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 16  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 17  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 18  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 19  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 20  NEW YORK STATE DEPARTMENT OF HEALTH STATE BOAR...
# 21  the licensee's registration period. Licensee s...
# 22  specialty, (“practice monitor’) proposed by Re...
# 23  Respondent shall have an approved successor in...
# 24  discharged for cause, which shall include but ...
# 25  shall include but not be limited to the inadeq...
# 26  replacement, if the Director does not approve ...
#
#                       Next 250 Words (Including Term)
# 0   defraud in the first degree (NY Penal Law 190....
# 1   fraud in the first degree (NY Penal Law 177.25...
# 2   defraud charge and imprisonment for two years ...
# 3   unlawful distribution of anabolic steroids and...
# 4   unlawful distribution of Oxycodone in violatio...
# 5   prescriptions to them for controlled substance...
# 6   prescribing controlled substances, opioids, an...
# 7   opioids, and other dangerous drugs without mai...
# 8   prescriptions. Although charged with negligenc...
# 9   prescribing practices for 15 patients, the Nan...
# 10  Prescription System) report prior to prescribi...
# 11  prescribing a controlled substance; and, that ...
# 12  unlawful distribution and dispensing of contro...
# 13  prescribing controlled substances, a practice ...
# 14  defraud or harm the public. SPECIFICATION OF C...
# 15  prescriptions for Phentermine, a schedule [V-c...
# 16  prescription and was unaware Respondent had do...
# 17  prescribing of controlled substances to patien...
# 18  prescribing controlled substances to patients ...
# 19  prescriptive authorization to prescribe, admin...
# 20  sexual nature. SPECIFICATION OF CHARGES Willfu...
# 21  description of Respondent's employment and pra...
# 22  prescribing information and office records. Th...
# 23  cause the practice monitor to report quarterly...
# 24  prescribing practice. Respondent shall cause t...
# 25  cause the practice supervisor to report within...
# 26         prescribing practice. These narrative Bev,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   File Name                            27 non-null     object
#  1   Page Marker                          27 non-null     object
#  2   Page Number                          27 non-null     int64
#  3   Matched Term                         27 non-null     object
#  4   Original Term                        27 non-null     object
#  5   Similarity Score                     27 non-null     float64
#  6   Search Term with 50 Words Context    27 non-null     object
#  7   Previous 250 Words (Including Term)  27 non-null     object
#  8   Next 250 Words (Including Term)      27 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.0+ KB

# %%
## convert to text
tab2text(df, "final_md_excerpt.txt")
# Out:
# final_md_excerpt.txt is in your local project folder.
# 'final_md_excerpt.txt'
