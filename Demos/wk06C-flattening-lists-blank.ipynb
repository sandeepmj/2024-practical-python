# %% [markdown]
# # Flattening a List of Iterables

# %%
## you have a list that contains lists
big_list = [[1, 2, 3], [4, 5, 6], [7], [8, 9]]

# %%
## let's do something simple like add 10 to each item in the list

# %%
## what actually is in this list?

# %% [markdown]
# ## Flatten with For Loop

# %% [markdown]
# ![Screen Shot 2022-10-17 at 1.25.17 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Flatten with List Comprehension

# %% [markdown]
# ![Screen Shot 2022-10-17 at 1.26.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# While the above techniques are all considered ```pythonic``` they aren't the most efficient or clean.
#
# Whenever you encounter lists within lists, or loops within loops, you just say to yourself:
#
# ## "There has got to be a better way!"
#
# Using built-in methods is usually the best approach.

# %% [markdown]
# ## ```itertools```
#
# ```itertools``` is a native Python module that allows efficient processing of iterables.
#
# <a href="https://docs.python.org/3/library/itertools.html">More info</a> on all itertools methods.

# %%
## use itertools

# %%
## run itertools
